# %%
import numpy as np
import gennoisy
from pca import pca
import matplotlib.pylab as plt
# %matplotlib inline

# %%
X,S,A,N = gennoisy.gennoisy()
plt.plot(X)
plt.title('Mixed Signals (3 channels)')
plt.figure()
plt.plot(S)
plt.title('Original Signals')

# %%
evals,evecs,m = pca(X,0)
rX = (X-m).dot(evecs.T).dot( np.linalg.inv(evecs.dot(evecs.T)))
plt.plot(rX)
plt.title('Rotated mixed')

# %%
evecs.T.dot(evecs) / len(evecs)
# Out:
# array([[  3.33333333e-01,   9.25185854e-17,   4.16333634e-17],
#        [  9.25185854e-17,   3.33333333e-01,  -6.93889390e-17],
#        [  4.16333634e-17,  -6.93889390e-17,   3.33333333e-01]])
