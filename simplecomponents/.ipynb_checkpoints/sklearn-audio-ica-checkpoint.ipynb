# %%
import numpy as np
import scipy.io.wavfile as wav
import scikits.audiolab
import sys, glob
from ica import ica
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ## Read the `wav` files.

# %%
# Read the wav files
files= glob.glob('../initialpitch/wavs/labmates/recording-*.wav')
source = []
for i,filename in enumerate(files):
    (rate,sig) = wav.read(filename)
    if len(sig.shape)==2:
        sig =sig[:,0].astype(np.float64)/sig[:,0].max()
    source+=[sig]
source = np.array(source)

# %% [markdown]
# ## Create a fake channel

# %%
A = np.random.randn( len(source), len(source) )
A -= A.min()
A /= A.max()

# Mixed signals together
X = A.dot(source)

# %% [markdown]
# ## Do ICA on signals

# %%
ivecs,m = ica(X, sigdim=1, n_components=len(X))
rX = (X.T-m).dot(ivecs).dot( np.linalg.inv(ivecs.T.dot(ivecs)))
plt.plot(rX)
plt.title('Rotated mixed')

# %%
for i in range(len(rX.T)):
    scikits.audiolab.play(rX[:,i], fs=rate)
